# %%
#Create a class Publisher (name). Derive class Book from Publisher with attributes title and author. Derive class Python from Book with attributes price and no_of_pages. Write a program that displays information about a Python book. Use base class constructor invocation and method overriding.
class Publisher:
    def __init__(self,pname):
        self.pubname=pname

    def display(self):
        print("Publisher Name:",self.pubname)

class Book(Publisher):
    def __init__(self,pname,bname,author):
        super().__init__(pname)
        self.title=bname
        self.auth=author

       def display(self):
        super().display()
        print("Book Title:",self.title)
        print("Author:",self.auth)

class Python(Book):
    def __init__(self,pname,title,au,price,np):
        super().__init__(pname,title,au)
        self.rate=price
        self.nop=np

       def display(self):
        super().display()  
        print("Price (Rs):",self.rate)
        print("Number of Pages:",self.nop)

p=input("Enter publisher name: ")
b=input("Enter book title: ")
a=input("Enter author name: ")
r=float(input("Enter price: "))
n=int(input("Enter number of pages: "))

book=Python(p,b,a,r,n)
print("\n Book Details")
book.display()
# Out:
# Enter publisher name:  Mathrubhmi Books
# Enter book title:  Abhimanyu
# Enter author name:  MT Vasudevan Nair
# Enter price:  399
# Enter number of pages:  458
#  Book Details
# Publisher Name: Mathrubhmi Books
# Book Title: Abhimanyu
# Author: MT Vasudevan Nair
# Price (Rs): 399.0
# Number of Pages: 458
