# %%
#write a python program to read a file line by line and store it into a list
with open("sample.txt","r") as file:
    lines=file.readlines()

print("Lines in file:")

print(lines)
# Out:
# Lines in file:
# ['Sreehari\n', 'Sidhu\n', 'Ihsan\n', 'Nihad\n', 'Jobin\n']

# %%
#python program to cody odd lines of one file to other
file1=input("Enter the source file")
file2=input("Enter the destination file")
f1=open(file1,"r")
f2=open(file2,"w")
i=0
for line in f1.readlines():
    i=i+1
    if i%2==0:
        continue
    f2.write(line)
f1.close()
f2.close()
print("odd lines of",file1,"is trasfered to",file2)
# Out:
# Enter the source file source.txt
# Enter the destination file destination.txt
# odd lines of source.txt is trasfered to destination.txt

# %%
#write a python program to read each row from a given csv file and print a list of strings
import csv
fname=input("Enter the csv file name:")
f1=open(fname,"r")
reader=csv.reader(f1)
for row in reader:
    print(row)
f1.close()
# Out:
# Enter the csv file name: sample.csv
# ['name', 'age', 'mark']
# ['ihsan', '18', '100']
# ['sidhu', '21', '200']
# ['shifu', '32', '300']

# %%
#write a python program to read specific column of a given CSV file and print the contents of the colums

import csv
fname=input("enter the CSV file name:")
with open(fname,"r") as f1:
    reader=csv.DictReader(f1)
    print("\nDEPARTMENT DETAILS:")
    print("........................................................")
    for row in reader:
        print("DEPARTMENT ID:",row['DeptId'],"DEPARTMENT NAME:",row['Deptname'])
# Out:
# enter the CSV file name: departments.csv
# DEPARTMENT DETAILS:
# ........................................................
# DEPARTMENT ID: 101 DEPARTMENT NAME: CSE
# DEPARTMENT ID: 102 DEPARTMENT NAME: ECE
# DEPARTMENT ID: 103 DEPARTMENT NAME: MECH
# DEPARTMENT ID: 104 DEPARTMENT NAME: CIVIL

# %%
#5. Write a Python program to write a Python dictionary to a csv file. After writing the CSV file read the CSV file and display the content.
import csv
data=[
    {"Name":"ihsan","Age":21,"Marks":99},
    {"Name":"shifu","Age":21,"Marks":78},
    {"Name":"sidhu","Age":23,"Marks":91}
]
with open("students_dict.csv","w",newline='') as file:
    fieldnames=["Name","Age","Marks"]
    writer=csv.DictWriter(file,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)
    print("Dictionary data written successfully!")
with open("students_dict.csv","r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# Dictionary data written successfully!
# ['Name', 'Age', 'Marks']
# ['ihsan', '21', '99']
# ['shifu', '21', '78']
# ['sidhu', '23', '91']
