# %%
#Q1.Write a Python program to read a file line by line and store it into a list.
with open("abtpy.txt","r")as file:
    lines=file.readlines()
print("Lines in file:")
print(lines)
# Out:
# Lines in file:
# ['Python is a interpreter language\n', 'Python is mainly used in ML and AI\n']
