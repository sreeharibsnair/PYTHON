# %%
#python program to cody odd lines of one file to other
file1=input("Enter the source file")
file2=input("Enter the destination file")
f1=open(file1,"r")
f2=open(file2,"w")
i=0
for line in f1.readlines():
    i=i+1
    if i%2==0:
        continue
    f2.write(line)
f1.close()
f2.close()
# Out:
# Enter the source file FileA.txt
# Enter the destination file abc.txt
